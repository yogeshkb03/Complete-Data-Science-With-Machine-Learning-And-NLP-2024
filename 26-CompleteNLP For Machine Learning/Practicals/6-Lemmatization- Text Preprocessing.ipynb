# %% [markdown]
# <a href="https://colab.research.google.com/github/yogeshkb03/Complete-Data-Science-With-Machine-Learning-And-NLP-2024/blob/main/26-CompleteNLP%20For%20Machine%20Learning/Practicals/6-Lemmatization-%20Text%20Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Wordnet Lemmatizer
# Lemmatization technique is like stemming. The output we will get after lemmatization is called ‘lemma’, which is a root word rather than root stem, the output of stemming. After lemmatization, we will be getting a valid word that means the same thing.
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. This class uses morphy() function to the WordNet CorpusReader class to find a lemma. Let us understand it with an example −

# %%
## Q&A,chatbots,text summarization
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()

# %%
'''
POS- Noun-n
verb-v
adjective-a
adverb-r
'''
lemmatizer.lemmatize("going",pos='v')
# Out:
# 'go'

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
for word in words:
    print(word+"---->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eat
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->history
# finally---->finally
# finalized---->finalize

# %%
lemmatizer.lemmatize("goes",pos='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize("fairly",pos='v'),lemmatizer.lemmatize("sportingly")
# Out:
# ('fairly', 'sportingly')

# %%
print('Hello')
# Out:
# Hello
